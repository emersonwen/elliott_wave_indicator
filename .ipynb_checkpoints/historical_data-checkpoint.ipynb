# %%
# Importing libraries from Historical-Crypto package
from Historic_Crypto import HistoricalData
from Historic_Crypto import Cryptocurrencies
from Historic_Crypto import LiveCryptoData
import pandas as pd
import plotly.graph_objects as go
from datetime import datetime

# %%
# Retrieve Ticker

Cryptocurrencies(coin_search = 'SOL', extended_output=False).find_crypto_pairs()
# Out:
# Connected to the CoinBase Pro API.
# Found 6 instances containing the term SOL.
# Extended Output is False, returning reduced dataset.
#            id display_name  fx_stablecoin max_slippage_percentage  status
# 53    SOL-EUR      SOL/EUR          False              0.03000000  online
# 74   SOL-USDT     SOL/USDT          False              0.03000000  online
# 85    SOL-ETH      SOL/ETH          False              0.03000000  online
# 141   SOL-USD      SOL/USD          False              0.03000000  online
# 145   SOL-BTC      SOL/BTC          False              0.03000000  online
# 175   SOL-GBP      SOL/GBP          False              0.03000000  online

# %%
sol_data = HistoricalData('SOL-USD',300,'2022-03-28-00-00').retrieve_data()
# Out:
# Checking input parameters are in the correct format.
# Formatting Dates.
# Checking if user supplied is available on the CoinBase Pro API.
# Connected to the CoinBase Pro API.
# Ticker 'SOL-USD' found at the CoinBase Pro API, continuing to extraction.
# Provisional Start: 2022-03-28T00:00:00
# Provisional End: 2022-03-29T01:00:00
# Data for chunk 1 of 34 extracted
# Provisional Start: 2022-03-29T01:00:00
# Provisional End: 2022-03-30T02:00:00
# Data for chunk 2 of 34 extracted
# Provisional Start: 2022-03-30T02:00:00
# Provisional End: 2022-03-31T03:00:00
# Data for chunk 3 of 34 extracted
# Provisional Start: 2022-03-31T03:00:00
# Provisional End: 2022-04-01T04:00:00
# Data for chunk 4 of 34 extracted
# Provisional Start: 2022-04-01T04:00:00
# Provisional End: 2022-04-02T05:00:00
# Data for chunk 5 of 34 extracted
# Provisional Start: 2022-04-02T05:00:00
# Provisional End: 2022-04-03T06:00:00
# Data for chunk 6 of 34 extracted
# Provisional Start: 2022-04-03T06:00:00
# ...

# %%
sol_data.head(25)
# Out:
#                         low    high    open   close     volume
# time
# 2022-03-28 00:05:00  106.38  106.87  106.69  106.72   7523.530
# 2022-03-28 00:10:00  106.34  106.79  106.72  106.41   5040.048
# 2022-03-28 00:15:00  106.32  106.68  106.42  106.39   3633.020
# 2022-03-28 00:20:00  106.22  106.51  106.41  106.23   5184.820
# 2022-03-28 00:25:00  106.14  106.44  106.25  106.31   2821.203
# 2022-03-28 00:30:00  106.31  107.68  106.32  107.27  16695.626
# 2022-03-28 00:35:00  106.89  107.64  107.28  106.91   6751.270
# 2022-03-28 00:40:00  106.57  107.15  106.98  106.71   8014.506
# 2022-03-28 00:45:00  105.70  106.70  106.70  106.00  16387.152
# 2022-03-28 00:50:00  105.75  106.22  106.00  106.11   5038.398
# 2022-03-28 00:55:00  105.79  106.18  106.12  106.06   7626.966
# 2022-03-28 01:00:00  105.64  106.11  106.04  105.84   7663.476
# 2022-03-28 01:05:00  105.80  106.05  105.83  105.94   3951.983
# 2022-03-28 01:10:00  105.81  106.10  105.95  106.04   3506.739
# ...

# %%
fig = go.Figure(data=[go.Candlestick(x=sol_data.index,
                open=sol_data['open'],
                high=sol_data['high'],
                low=sol_data['low'],
                close=sol_data['close'])])

fig.show()
